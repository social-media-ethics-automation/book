# %% [markdown]
# # Demo: Extra Data From Twitter

# %% [markdown]
# ## Set up

# %%
# make sure tweepy library is installed
import tweepy

# %%
# load my twitter keys
import my_bot_keys

# %%
# log into tweepy
client = tweepy.Client(
    bearer_token=my_bot_keys.bearer_token,
    consumer_key=my_bot_keys.consumer_key, consumer_secret=my_bot_keys.consumer_secret,                   
    access_token=my_bot_keys.access_token, access_token_secret=my_bot_keys.access_token_secret
)

# %% [markdown]
# ## Find tweets with images
# Resources:
# * Tweepy documentation (for Twitter API v2): https://docs.tweepy.org/en/stable/client.html
# * Some examples of how to use Tweepy: https://dev.to/twitterdev/a-comprehensive-guide-for-using-the-twitter-api-v2-using-tweepy-in-python-15d9

# %%
#query = "from:KSeattleWeather -is:retweet has:images"
query = "dog -is:retweet has:images"

tweets = client.search_recent_tweets(query=query,
                                    expansions='attachments.media_keys', #tell twitter to download the media related to this tweet
                                    media_fields=['preview_image_url', 'height', 'width']  # when getting the media, make sure to include this info
                                    )

# print the infromation from the "media" includes 
# Note: the media information is stored separately in the results
print(tweets.includes['media'])
for media in tweets.includes['media']:
    print(media)
    print(media.preview_image_url)
    print(media.height)
    print(media.width)
    print()
    

# clever trick to make lookup table for media_keys saved in the variable "media"
media = {m["media_key"]: m for m in tweets.includes['media']}

# go through each tweet
for tweet in tweets.data:
    # use the tweet id to make a link to this specific tweet
    print('https://twitter.com/twitter/statuses/' + str(tweet.id))
    
    # print the contents of the tweet
    print(tweet)
    
    #get the media keys for this tweet
    attachments = tweet.data['attachments']
    media_keys = attachments['media_keys']
    
    # go through each of the photos (or other media)
    for media_key in media_keys:
        # find that media object using the media lookup table
        media_info = media[media_key]
        print(media_info.type)
        print("  media_key: " + media_info.media_key)
        print("  height: " + str(media_info.height))
        print("  width: " + str(media_info.width))
        
    print()
# Out:
# [<Media media_key=3_1486838563941806081 type=photo>, <Media media_key=16_1486838567636770819 type=animated_gif>, <Media media_key=3_1486838416440446978 type=photo>, <Media media_key=3_1486838375923564545 type=photo>, <Media media_key=3_1486838366100361217 type=photo>, <Media media_key=3_1486838344176836619 type=photo>, <Media media_key=3_1486838312824414211 type=photo>, <Media media_key=3_1486838292288991237 type=photo>, <Media media_key=3_1486838268897361923 type=photo>, <Media media_key=16_1486838246340505610 type=animated_gif>]
# <Media media_key=3_1486838563941806081 type=photo>
# None
# 549
# 730
#
# <Media media_key=16_1486838567636770819 type=animated_gif>
# https://pbs.twimg.com/tweet_video_thumb/FKJPzLZXIAMmKgF.jpg
# 220
# 244
#
# <Media media_key=3_1486838416440446978 type=photo>
# None
# 2048
# 946
#
# <Media media_key=3_1486838375923564545 type=photo>
# None
# 2048
# 1536
#
# <Media media_key=3_1486838366100361217 type=photo>
# None
# 721
# 960
#
# <Media media_key=3_1486838344176836619 type=photo>
# None
# 1706
# 1080
#
# <Media media_key=3_1486838312824414211 type=photo>
# None
# 1600
# 1096
#
# <Media media_key=3_1486838292288991237 type=photo>
# None
# 2048
# 1536
#
# <Media media_key=3_1486838268897361923 type=photo>
# None
# 415
# 739
#
# <Media media_key=16_1486838246340505610 type=animated_gif>
# https://pbs.twimg.com/tweet_video_thumb/FKJPgeeXMAorbMb.jpg
# 282
# 374
#
# https://twitter.com/twitter/statuses/1486838578889957377
# COPPER – LOST DOG IN MOUNT OLIVE, IL, 62069
#
# More Details:
# https://t.co/dTILWQPFSb
# #LostPetFlyer
# #LostDog #LostPet #MissingDog
# #LostCat #LostPetFlyer #FoundPet https://t.co/8dyOPyJpjj
# photo
#   media_key: 3_1486838563941806081
#   height: 549
#   width: 730
#
# https://twitter.com/twitter/statuses/1486838575211720714
# @circles_and I'm so sorry. Its the hardest part of being a pet parent.
#
# My dog, Prancer died last Friday.
# May your memories sustain you. https://t.co/NjOaOyiAN6
# animated_gif
#   media_key: 16_1486838567636770819
#   height: 220
#   width: 244
#
# https://twitter.com/twitter/statuses/1486838422903865347
# @Jsorrentino123 Shiloh.  I rescued him.  Literally just on the table to be killed. 💔. People are so mean. He was abused. He ate a couch and other things. It took a few years and lots of Patients. He is a great dog I’ve had him for five years now and I just adore him https://t.co/efSmbiTxBv
# photo
#   media_key: 3_1486838416440446978
#   height: 2048
#   width: 946
#
# https://twitter.com/twitter/statuses/1486838382030381059
# Yay I’m…mini(ish) #BillHader arrived today…ummm I hope my dog doesn’t pee on him; that would be bad… https://t.co/H7HpvArkeN
# photo
#   media_key: 3_1486838375923564545
#   height: 2048
#   width: 1536
#
# https://twitter.com/twitter/statuses/1486838375382282243
# Life imitates art.
# #dogs #doggo #dog #animals #dogsoftwitter #DogsofTwittter https://t.co/FczLiz3t8L
# photo
#   media_key: 3_1486838366100361217
#   height: 721
#   width: 960
#
# https://twitter.com/twitter/statuses/1486838350006956032
# This is Natalie Dive Tom Chaplins wife who dressed him like poodle lap dog https://t.co/1jFzmTzP8M
# photo
#   media_key: 3_1486838344176836619
#   height: 1706
#   width: 1080
#
# https://twitter.com/twitter/statuses/1486838339974139910
# what da dog doin https://t.co/zmmPldhtkk
# photo
#   media_key: 3_1486838312824414211
#   height: 1600
#   width: 1096
#
# https://twitter.com/twitter/statuses/1486838301914910720
# @Krypass what mix is your dog https://t.co/FLP3JHUoRG
# photo
#   media_key: 3_1486838292288991237
#   height: 2048
#   width: 1536
#
# https://twitter.com/twitter/statuses/1486838274119274496
# @airindiain He was aviator. #Chandra #MarathonRunner After #ratantata all failed projects. #Nano . They bring expat to run their business. Kicked out #Mistry who was the former Chairman. Don’t be a dog which believes in being loyal. https://t.co/5QHXLv5pYg
# photo
#   media_key: 3_1486838268897361923
#   height: 415
#   width: 739
#
# https://twitter.com/twitter/statuses/1486838252283781121
# And no, I couldn’t bring back the dog. https://t.co/ICm4LRvSK9
# animated_gif
#   media_key: 16_1486838246340505610
#   height: 282
#   width: 374

# %%
#query = "from:KSeattleWeather -is:retweet has:images"
query = "dog -is:retweet has:images"

tweets = client.search_recent_tweets(query=query,
                                    expansions='author_id', #tell twitter to download the author related to this tweet
                                    user_fields=['profile_image_url']  # when getting the author, make sure to include this info
                                    )

   

# clever trick to make lookup table for user ids saved in the variable "users"
users = {u["id"]: u for u in tweets.includes['users']}

# go through each tweet
for tweet in tweets.data:
    # use the tweet id to make a link to this specific tweet
    print('https://twitter.com/twitter/statuses/' + str(tweet.id))
    
    # print the contents of the tweet
    print(tweet)
    
    #get the authorid for this tweet
    author_id = tweet.author_id
    
    # get the author info
    author = users[tweet.author_id]
    
    print(author)
    print("author profile image: " + author.profile_image_url)
        
    print()
# Out:
# https://twitter.com/twitter/statuses/1486839967175385097
# what da dog doin https://t.co/YxChXXsa9v
# NSFlushes
# author profile image: https://pbs.twimg.com/profile_images/918964218027581442/5jbPBTFR_normal.jpg
#
# https://twitter.com/twitter/statuses/1486839953652862977
# liams dog waiting to steal liams phone to tweet https://t.co/ezLKo29L3v
# singularzcarus
# author profile image: https://pbs.twimg.com/profile_images/1485365829034250257/8Ri6VyYL_normal.jpg
#
# https://twitter.com/twitter/statuses/1486839934493229057
# It's been 8 years today that I lost my Brother Jeff, my BEST Friend we were SO tight. He died at 46 from Alcohol abuse after we lost our Mom, he couldn't cope, I took his Dog and lost her in Nov. It was only us 3, now it's just me, life has never been the same. https://t.co/qoZDHdS2Vc
# HowellMI69
# author profile image: https://pbs.twimg.com/profile_images/691684415295131650/u1lqwf2p_normal.jpg
#
# https://twitter.com/twitter/statuses/1486839921038004224
# @aceCourtBot @_Lord_Bidoof_ @dog_raper28 @VerdantLights @WonderYurr @NoHonig @XxCrash97xX @CodeSpiritAxis @purplednft @_Radonio @NeverNoodle @matt_dm29 @i305louise @ScoobyStu82_ @ShellC_blts @ggssgtheorig @Tearii__ @GoffytoSSGSS @wicecwispiez @BlutheRange @x0v0x__ @Kittlegairy_ @rrs_02 @Slayer9915 @Werme__ @amluyy @blacKxngg @aqurids @PieNinja_ @TheGimmickAcc it’s me! https://t.co/czUsY22HK2
# Moon_lol1
# author profile image: https://pbs.twimg.com/profile_images/1476069012673019906/5x63pQre_normal.jpg
#
# https://twitter.com/twitter/statuses/1486839895335350279
# NIGGA FLEXIN ON YOU IS MY DUTY I'M THE BIG DOG MY NICKNAME IS SCOOBY https://t.co/Hl249ZHYjM
# lsol8tion
# author profile image: https://pbs.twimg.com/profile_images/1477061180200034309/7-8cR45U_normal.jpg
#
# https://twitter.com/twitter/statuses/1486839887756210183
# Singlehandedly bringing the dog filter back from the dead https://t.co/ZifdAFDSXD
# strwbeerry
# author profile image: https://pbs.twimg.com/profile_images/1485448292406341639/p18gmAc9_normal.jpg
#
# https://twitter.com/twitter/statuses/1486839864955846661
# いいねの数×24時間 無料で公開されるアプリ🖥️
#
# https://t.co/2Tc0GJIxjw https://t.co/sAeOgnOpVu
# AstieDog
# author profile image: https://pbs.twimg.com/profile_images/1474874275761115136/v2A7TFig_normal.jpg
#
# https://twitter.com/twitter/statuses/1486839836904464387
# @notonemorevet @dog_rates @parkertheboatdog says ahoy there https://t.co/mZ4CUfZJGL
# Bulldogvoce
# author profile image: https://pbs.twimg.com/profile_images/634956380722581504/9_RhAQyW_normal.jpg
#
# https://twitter.com/twitter/statuses/1486839804012769284
# @RealMichaelKay @DonLagreca @Rosenbergradio
# Watching you guys on yes w my dog and my 6 day old rt now! https://t.co/9rrZIdp1wR
# MikeDepinto3rd
# author profile image: https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png
#
# https://twitter.com/twitter/statuses/1486839743128248321
# @plumberdave There are no good words to console you when you lose the unconditional love of a good dog. I am very sorry. https://t.co/oIBzQMZif0
# CoachMarcWilson
# author profile image: https://pbs.twimg.com/profile_images/753187898199986181/wxH14AQ9_normal.jpg
