# %% [markdown]
# # Demo: Alt-text From Twitter
# Now that we've seen how to select additional information about Tweet images and data, let's search for images and look up some alt-text:

# %% [markdown]
# ## Normal Tweepy Set-Up

# %%
import tweepy

# %% [markdown]
# (optional) use the fake version of tweepy, so you don’t have to use real twitter developer access passwords

# %%
# Load all your developer access passwords into Python
# TODO: Put your twitter account's special developer access passwords below:
bearer_token = "n4tossfgsafs_fake_bearer_token_isa53#$%$"
consumer_key = "sa@#4@fdfdsa_fake_consumer_key_$%DSG#%DG"
consumer_secret = "45adf$T$A_fake_consumer_secret_JESdsg"
access_token = "56sd5Ss4tsea_fake_access_token_%YE%hDsdr"
access_token_secret = "j^$dr_fake_consumer_key_^A5s#DR5s"

# %%
# Give the tweepy code your developer access passwords so
# it can perform twitter actions
client = tweepy.Client(
   bearer_token=bearer_token,
   consumer_key=consumer_key, consumer_secret=consumer_secret,
   access_token=access_token, access_token_secret=access_token_secret
)

# %% [markdown]
# ## Do a search for tweets, loop through the tweets and display the alt-text information

# %%
query = "dog -is:retweet has:images"

tweet_search_results = client.search_recent_tweets(
                                    query=query,
                                    expansions='attachments.media_keys', #tell twitter to download the media related to this tweet
                                    media_fields=['alt_text', 'url'],  # when getting the media, make sure to include this info
                                    max_results=100
                                    )


# make media_lookup dictionary
media_lookup = {m["media_key"]: m for m in tweet_search_results.includes['media']}

# go through each tweet
for tweet in tweet_search_results.data:
    
    # use the tweet id to make a link to this specific tweet
    print('https://twitter.com/twitter/statuses/' + str(tweet.id))
    
    # print the contents of the tweet
    print(tweet)
    
    # print the info on "attachments" for this tweet
    #  in this case, it will be the media_keys
    
    #get the media keys for this tweet
    media_keys = tweet.data['attachments']['media_keys']
    
    for media_key in media_keys:
        # lookup the info about this particular media_key
        media_info = media_lookup[media_key]

        # print out some info about this piece of media
        print("  type: " + media_info.type)
        print("  alt_text: " + str(media_info.alt_text))
        print("  url: " + str(media_info.url))
        print()
       
    # display a clear divider so we can more easily see each tweet
    print()
    print("------------------------")
    print()
# Out:
# https://twitter.com/twitter/statuses/1584807318310780928
# @AindritaR Ratioed by a bunny. You don't have a dog. That's a pussy https://t.co/fQaSWHIQtb
#   type: photo
#   alt_text: None
#   url: https://pbs.twimg.com/media/Ff5d2x7agAEHOdt.jpg
#
#
# ------------------------
#
# https://twitter.com/twitter/statuses/1584807301365788672
# @AandCo_ We LOVE our annual Halloween crafts and Pumpking carving night 👻🖤🎃
#
# The dog however would be happy if we skipped it this year 🤣
#
# Amazon is so handy, we love using Prime, especially on Black Friday 🖤
#
# @JelChapito
# @Emma_E27
# @emilyalicebird https://t.co/br23EZYe6n
#   type: photo
#   alt_text: None
#   url: https://pbs.twimg.com/media/Ff5d10CWQAMakYa.jpg
#
#
# ------------------------
#
# https://twitter.com/twitter/statuses/1584807220885307393
# Guiding Eyes For The Blind brings puppies in training to LCCC – Morning Journal see full article - https://t.co/rZDCjOjmxh https://t.co/9uelGvpUJg
#   type: photo
#   alt_text: None
#   url: https://pbs.twimg.com/media/Ff5dxNOXEAADu_Z.jpg
#
#
# ------------------------
#
# https://twitter.com/twitter/statuses/1584807193286791168
# 🏖 Dog beach Sète Marseillan
#
# 📍 8HH8+4P, 34200 Sète, France
#
# 🗺 https://t.co/IdmKCmyP5z https://t.co/wZRWrSlM3d
#   type: photo
#   alt_text: None
#   url: https://pbs.twimg.com/media/Ff5dvmMXkAMPFUM.jpg
#
#   type: photo
#   alt_text: None
#   url: https://pbs.twimg.com/media/Ff5dvmPX0AAVVrz.jpg
#
#   type: photo
#   alt_text: None
#   url: https://pbs.twimg.com/media/Ff5dvmaXoAEKJoO.jpg
#
#   type: photo
#   alt_text: None
#   url: https://pbs.twimg.com/media/Ff5dvmSXoAA05DK.jpg
#
#
# ------------------------
#
# https://twitter.com/twitter/statuses/1584807119043584000
# @ChemicalShin this is a dog man dogs. https://t.co/gWhvP5EqVt
#   type: photo
#   alt_text: None
#   url: https://pbs.twimg.com/media/Ff5drCuaUAApvp0.jpg
#
#
# ------------------------
#
# https://twitter.com/twitter/statuses/1584807069508861953
# @rovercrc No one can stop this Epic
# Buff Dog going jump higher
# HULK INU going to the Moon 🌕
#
# #HULK
# $HULK #HULKINU
# #STRONGESTINU #HULKARMY
# #ETH #NFT #NFTutilities
#
# @JakeGagain @Yourpop8
# @hulkinuofficial @AdamShelton
# @BSCGemAlert @1goonrich https://t.co/NLelmGzwVp
#   type: photo
#   alt_text: None
#   url: https://pbs.twimg.com/media/Ff5doXJaYAEvFae.jpg
#
#
# ------------------------
#
# https://twitter.com/twitter/statuses/1584807060100640768
# Evie’s campaign is so far reaching. We were asked for help by a mum who’s daughter wants to be Mary Anning for Halloween this year. They live in Oklahoma! Evie said ‘The key is a basket, a bonnet and a stuffed black and white dog!’ How amazing does Charlotte look? #Halloween https://t.co/lYLv6Ay0Jy
#   type: photo
#   alt_text: None
#   url: https://pbs.twimg.com/media/Ff5dmA6WQAA08r3.jpg
#
#
# ------------------------
#
# https://twitter.com/twitter/statuses/1584807051834032128
# Let's celebrate #nationaldogadoptionday the right way.
#
# Please share your rescue dog photos!
#
# This is Danny. Our rescue dog who came from Ireland. He was 24 hours away from being put to sleep. So every day with him is a real gift. #bringjoyadoptadog https://t.co/OfayZnmWTp
#   type: photo
#   alt_text: None
#   url: https://pbs.twimg.com/media/Ff5dgJRXgAAQAm7.jpg
#
#
# ------------------------
#
# https://twitter.com/twitter/statuses/1584806970602967040
# @Pops__o Just had lovely dog walk on the beach in Norfolk https://t.co/iCfBh94Nq8
#   type: photo
#   alt_text: None
#   url: https://pbs.twimg.com/media/Ff5dh2VWQAgZSSd.jpg
#
#
# ------------------------
#
# https://twitter.com/twitter/statuses/1584806963958915072
# n/a Reflective Double Leash Pet Dog Leash Leash for Running Free Hand Leash Chain for Large ... see full article - https://t.co/Jk4YJqT5C9 https://t.co/ppDU0gjc2E
#   type: photo
#   alt_text: None
#   url: https://pbs.twimg.com/media/Ff5diPKXwAILGH-.jpg
#
#
# ------------------------
#
# https://twitter.com/twitter/statuses/1584806926684409857
# @carterefe__ The patient dog eats the fattest bone... https://t.co/fEl6flaOaI
#   type: photo
#   alt_text: None
#   url: https://pbs.twimg.com/media/Ff5dfvkWYAEJEN5.jpg
#
#
# ------------------------
#
# https://twitter.com/twitter/statuses/1584806914617024512
# @taylorbracewell Following on all socials 🙌
# We LOVE our annual Halloween crafts and Pumpking carving night 👻🖤🎃
# The dog however would be happy if we skipped it this year 🤣
# My boy would be so happy with these treats 🧙‍♀️
#
# @Pearl_of_Kent
# @MTB_Cycler
# @JelChapito https://t.co/4LfFTbWDmm
#   type: photo
#   alt_text: None
#   url: https://pbs.twimg.com/media/Ff5dfS2WYAAKaQJ.jpg
#
#
# ------------------------
#
# https://twitter.com/twitter/statuses/1584806830076985344
# The quick brown fox jumps over the lazy dog. #followback #follow https://t.co/10EhYI6Xwj
#   type: photo
#   alt_text: None
#   url: https://pbs.twimg.com/media/Ff5daQnXEAEdPty.jpg
#
#
# ------------------------
#
# https://twitter.com/twitter/statuses/1584806796761481216
# Heather Grey Thermal Dog Pajamas https://t.co/OjxEp9c2BL
#
# #happybreathdog https://t.co/Jeb93ZmGkZ
#   type: photo
#   alt_text: None
#   url: https://pbs.twimg.com/media/Ff5dYVFXoAA0z_I.jpg
#
#   type: photo
#   alt_text: None
#   url: https://pbs.twimg.com/media/Ff5dYekWAAIJAOv.jpg
#
#
# ------------------------
#
# https://twitter.com/twitter/statuses/1584806781523726337
# @MattyAngelNZ @AuntyFeeble Definitely just like this dog 🐕 https://t.co/OBxOiq9WeK
#   type: photo
#   alt_text: None
#   url: https://pbs.twimg.com/media/Ff5dXY0acAAwZSE.jpg
#
#
# ------------------------
#
# https://twitter.com/twitter/statuses/1584806780323786752
# The dog makes the duck happy. Love🐶💚🧡
#
# @milephakphum #MilePhakphum
# @Nnattawin1 #Nnattawin https://t.co/qu7nv7dtak
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [22], in <cell line: 15>()
#      21 print(tweet)
#      23 # print the info on "attachments" for this tweet
#      24 #  in this case, it will be the media_keys
#      25
#      26 #get the media keys for this tweet
# ---> 27 media_keys = tweet.data['attachments']['media_keys']
#      29 for media_key in media_keys:
#      30     # lookup the info about this particular media_key
#      31     media_info = media_lookup[media_key]
#
# KeyError: 'attachments'
